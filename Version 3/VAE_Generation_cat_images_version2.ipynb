# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from azure.storage.blob import BlobServiceClient, generate_blob_sas, BlobSasPermissions
from datetime import datetime, timedelta
import urllib.request
from PIL import Image
import numpy as np
import time
# Out:
# 2023-10-22 04:26:48.054310: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-22 04:26:48.829269: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-10-22 04:26:48.829340: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-10-22 04:26:48.829347: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
account = "test"   # Azure account name
key = "test"      # Azure Storage account access key  
connect_str = "test"
container = "images"
blob_service_client = BlobServiceClient.from_connection_string(connect_str)

# %%
def generate_SAS():
    blob_list = []
    container_client_analysis = blob_service_client.get_container_client(container=container)

    
    blob_list = []
    for blob_i in container_client_analysis.list_blobs():
        blob_list.append(blob_i.name)
        
    sas_url_lst = []
    
    for j in range(len(blob_list)):
        sas_analysis = generate_blob_sas(account_name = account,
                        container_name = container,
                        blob_name = blob_list[j],
                        account_key=key,
                        permission=BlobSasPermissions(read=True),
                        expiry=datetime.utcnow() + timedelta(hours=1))
        sas_url = 'https://' + account+'.blob.core.windows.net/' + container + '/' + blob_list[j] + '?' + sas_analysis
        sas_url_lst.append(sas_url)
    return sas_url_lst

# %%
x= generate_SAS()

# %%
def load_dataset():
    lst_img = []
    # Open the image file
    #y = x[:100]
    for i in x:
        image_data = urllib.request.urlopen(i)
        image = Image.open(image_data)
        image = image.resize((50,50))
        image_array = np.array(image)
        lst_img.append(image_array)
        #print(image_array.shape)

    arr_img = np.array(lst_img)
    #arr_img = np.array(lst_img)
    split_ratio = 0.8
    np.random.shuffle(arr_img)
    size = int(arr_img.shape[0]*split_ratio) 
    training, test = arr_img[:size,:], arr_img[size:,:]
    return training,test

# %%
x_train,x_test = load_dataset()

# %%
x_test.shape
# Out:
# (2500, 50, 50)

# %%
test_image = x_train[0]

# %%
test_image
# Out:
# array([[ 35,  38,  37, ...,  63,  65,  49],
#        [ 40,  40,  41, ...,  64,  68,  53],
#        [ 49,  46,  48, ...,  65,  70,  57],
#        ...,
#        [ 98, 108, 110, ..., 108, 115, 116],
#        [101, 109, 108, ...,  97,  86, 117],
#        [110, 104, 107, ...,  74,  72,  99]], dtype=uint8)

# %%
plt.imshow(test_image,cmap="gray")
plt.show()

# %%
x_train = x_train.astype("float32") / 255.0
x_train = tf.expand_dims(x_train, -1)
x_test = x_test.astype("float32") / 255.0
x_test = tf.expand_dims(x_test, -1)

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 128

encoder_inputs = keras.Input(shape=(50 , 50, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = keras.layers.BatchNormalization()(x)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = layers.Conv2D(128, 3, activation="relu", strides=2, padding="same")(x)
x = keras.layers.BatchNormalization()(x)
#x = layers.Conv2D(256, 3, activation="relu", strides=2, padding="same")(x)
#x = layers.Conv2D(512, 3, activation="relu", strides=2, padding="same")(x)
#x = layers.Conv2D(1024, 32, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
#x = layers.Dense(512, activation="relu")(x)
#x = layers.Dense(1024, activation="relu")(x)
x = layers.Dense(512, activation="relu")(x)
x = layers.Dense(256, activation="relu")(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_19 (InputLayer)          [(None, 50, 50, 1)]  0           []
#
#  conv2d_27 (Conv2D)             (None, 25, 25, 32)   320         ['input_19[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 25, 25, 32)  128         ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (None, 13, 13, 64)   18496       ['batch_normalization_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 13, 13, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 128)    73856       ['batch_normalization_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 7, 7, 128)   512         ['conv2d_29[0][0]']
#  ormalization)
#
#  flatten_9 (Flatten)            (None, 6272)         0           ['batch_normalization_56[0][0]']
#
#  dense_27 (Dense)               (None, 512)          3211776     ['flatten_9[0][0]']
#
#  dense_28 (Dense)               (None, 256)          131328      ['dense_27[0][0]']
#
#  z_mean (Dense)                 (None, 128)          32896       ['dense_28[0][0]']
#
#  z_log_var (Dense)              (None, 128)          32896       ['dense_28[0][0]']
#
#  sampling_9 (Sampling)          (None, 128)          0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 3,502,464
# Trainable params: 3,502,016
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(25* 25 *128 , activation="relu")(latent_inputs)
x = layers.Reshape((25, 25, 128))(x)
#x = layers.Conv2DTranspose(512, 1, activation="relu", strides=1, padding="same")(x)
#x = layers.Conv2DTranspose(512, 1, activation="relu", strides=1, padding="same")(x)
x = layers.Conv2DTranspose(256, 1, activation="relu", strides=1, padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(128, 3, activation="relu", strides=2, padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=1, padding="same")(x)
x = keras.layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=1, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 128)]             0
#
#  dense_29 (Dense)            (None, 80000)             10320000
#
#  reshape_9 (Reshape)         (None, 25, 25, 128)       0
#
#  conv2d_transpose_45 (Conv2D  (None, 25, 25, 256)      33024
#  Transpose)
#
#  batch_normalization_57 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_transpose_46 (Conv2D  (None, 50, 50, 128)      295040
#  Transpose)
#
#  batch_normalization_58 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_transpose_47 (Conv2D  (None, 50, 50, 64)       73792
#  Transpose)
#
#  batch_normalization_59 (Bat  (None, 50, 50, 64)       256
#  chNormalization)
#
#  conv2d_transpose_48 (Conv2D  (None, 50, 50, 32)       18464
#  Transpose)
#
#  conv2d_transpose_49 (Conv2D  (None, 50, 50, 1)        289
#  Transpose)
#
# =================================================================
# Total params: 10,742,401
# Trainable params: 10,741,505
# Non-trainable params: 896
# _________________________________________________________________

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer='adam', loss='binary_crossentropy')
#vae.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001, loss='binary_crossentropy'))
vae.fit(x_train, epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 16s 139ms/step - loss: 1685.8996 - reconstruction_loss: 1632.3947 - kl_loss: 10.6756
# Epoch 2/100
# 79/79 [==============================] - 11s 138ms/step - loss: 1574.4240 - reconstruction_loss: 1547.5510 - kl_loss: 20.5660
# Epoch 3/100
# 79/79 [==============================] - 11s 139ms/step - loss: 1552.2069 - reconstruction_loss: 1524.9297 - kl_loss: 25.0799
# Epoch 4/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1540.4894 - reconstruction_loss: 1510.9615 - kl_loss: 27.4057
# Epoch 5/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1532.1509 - reconstruction_loss: 1500.3605 - kl_loss: 28.6862
# Epoch 6/100
# 79/79 [==============================] - 11s 141ms/step - loss: 1525.8778 - reconstruction_loss: 1493.4550 - kl_loss: 28.7649
# Epoch 7/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1521.4359 - reconstruction_loss: 1487.2885 - kl_loss: 28.7152
# Epoch 8/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1513.8917 - reconstruction_loss: 1480.3651 - kl_loss: 29.3348
# Epoch 9/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1504.2209 - reconstruction_loss: 1475.5413 - kl_loss: 29.4984
# Epoch 10/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1502.9032 - reconstruction_loss: 1470.7831 - kl_loss: 29.8304
# Epoch 11/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1498.7253 - reconstruction_loss: 1468.2990 - kl_loss: 29.6306
# Epoch 12/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1495.1618 - reconstruction_loss: 1466.7167 - kl_loss: 29.6963
# Epoch 13/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1494.1154 - reconstruction_loss: 1464.8251 - kl_loss: 29.8165
# Epoch 14/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1493.3355 - reconstruction_loss: 1463.4487 - kl_loss: 29.9819
# Epoch 15/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1492.9169 - reconstruction_loss: 1463.1097 - kl_loss: 30.1639
# Epoch 16/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1491.6488 - reconstruction_loss: 1460.6244 - kl_loss: 30.6136
# Epoch 17/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1492.4620 - reconstruction_loss: 1460.6855 - kl_loss: 30.7327
# Epoch 18/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1490.2481 - reconstruction_loss: 1459.5414 - kl_loss: 30.9733
# Epoch 19/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1488.2344 - reconstruction_loss: 1458.7351 - kl_loss: 31.1001
# Epoch 20/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1486.5340 - reconstruction_loss: 1457.1941 - kl_loss: 31.4410
# Epoch 21/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1491.4387 - reconstruction_loss: 1456.1646 - kl_loss: 31.5401
# Epoch 22/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1491.4746 - reconstruction_loss: 1456.4607 - kl_loss: 31.7765
# Epoch 23/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1487.6028 - reconstruction_loss: 1455.0483 - kl_loss: 32.0108
# Epoch 24/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1484.6350 - reconstruction_loss: 1454.3271 - kl_loss: 32.2405
# Epoch 25/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1486.2428 - reconstruction_loss: 1453.9376 - kl_loss: 32.4275
# Epoch 26/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1485.6926 - reconstruction_loss: 1453.3367 - kl_loss: 32.6085
# Epoch 27/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1485.1282 - reconstruction_loss: 1452.0214 - kl_loss: 32.9518
# Epoch 28/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1483.5298 - reconstruction_loss: 1452.0702 - kl_loss: 32.9266
# Epoch 29/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1483.4531 - reconstruction_loss: 1450.5588 - kl_loss: 33.0985
# Epoch 30/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1482.1075 - reconstruction_loss: 1450.1372 - kl_loss: 33.3311
# Epoch 31/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1485.6678 - reconstruction_loss: 1450.0497 - kl_loss: 33.3147
# Epoch 32/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1484.1563 - reconstruction_loss: 1449.6425 - kl_loss: 33.5664
# Epoch 33/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1484.8549 - reconstruction_loss: 1449.2440 - kl_loss: 33.5465
# Epoch 34/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1481.6270 - reconstruction_loss: 1447.5887 - kl_loss: 33.8043
# Epoch 35/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1483.3184 - reconstruction_loss: 1447.7343 - kl_loss: 33.8651
# Epoch 36/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1480.8152 - reconstruction_loss: 1446.4465 - kl_loss: 34.1357
# Epoch 37/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1480.5678 - reconstruction_loss: 1448.1239 - kl_loss: 33.9737
# Epoch 38/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1479.5636 - reconstruction_loss: 1446.2616 - kl_loss: 34.1945
# Epoch 39/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1479.5143 - reconstruction_loss: 1446.7935 - kl_loss: 34.3133
# Epoch 40/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1478.8321 - reconstruction_loss: 1445.5175 - kl_loss: 34.3570
# Epoch 41/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1477.1476 - reconstruction_loss: 1444.5906 - kl_loss: 34.5285
# Epoch 42/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1480.5562 - reconstruction_loss: 1444.8821 - kl_loss: 34.6129
# Epoch 43/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1478.1247 - reconstruction_loss: 1444.6274 - kl_loss: 34.6675
# Epoch 44/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1475.1899 - reconstruction_loss: 1442.8008 - kl_loss: 34.8983
# Epoch 45/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1481.0490 - reconstruction_loss: 1442.2854 - kl_loss: 34.8987
# Epoch 46/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1478.3282 - reconstruction_loss: 1442.3523 - kl_loss: 35.0416
# Epoch 47/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1478.1423 - reconstruction_loss: 1442.1267 - kl_loss: 35.1704
# Epoch 48/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1476.4550 - reconstruction_loss: 1441.3127 - kl_loss: 35.2822
# Epoch 49/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1477.0143 - reconstruction_loss: 1441.7560 - kl_loss: 35.2255
# Epoch 50/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1475.1766 - reconstruction_loss: 1440.8643 - kl_loss: 35.3419
# Epoch 51/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1476.8986 - reconstruction_loss: 1440.7670 - kl_loss: 35.3105
# Epoch 52/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1475.6519 - reconstruction_loss: 1439.7284 - kl_loss: 35.4970
# Epoch 53/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1473.2556 - reconstruction_loss: 1439.2013 - kl_loss: 35.6793
# Epoch 54/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1474.4602 - reconstruction_loss: 1438.9752 - kl_loss: 35.6360
# Epoch 55/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1476.1953 - reconstruction_loss: 1439.6783 - kl_loss: 35.5702
# Epoch 56/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1472.0111 - reconstruction_loss: 1439.5446 - kl_loss: 35.7464
# Epoch 57/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1475.2430 - reconstruction_loss: 1438.9240 - kl_loss: 35.7502
# Epoch 58/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1472.9357 - reconstruction_loss: 1438.2977 - kl_loss: 35.7447
# Epoch 59/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1474.6216 - reconstruction_loss: 1437.8212 - kl_loss: 35.9487
# Epoch 60/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1475.3359 - reconstruction_loss: 1436.4554 - kl_loss: 36.0637
# Epoch 61/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1472.2251 - reconstruction_loss: 1435.5990 - kl_loss: 36.0487
# Epoch 62/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1471.4213 - reconstruction_loss: 1435.7762 - kl_loss: 36.0846
# Epoch 63/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1473.2214 - reconstruction_loss: 1435.6971 - kl_loss: 36.2028
# Epoch 64/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1472.6235 - reconstruction_loss: 1437.0699 - kl_loss: 36.2014
# Epoch 65/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1470.6468 - reconstruction_loss: 1434.9341 - kl_loss: 36.1563
# Epoch 66/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1470.0982 - reconstruction_loss: 1435.8177 - kl_loss: 36.1930
# Epoch 67/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1467.9854 - reconstruction_loss: 1434.5575 - kl_loss: 36.2800
# Epoch 68/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1470.1802 - reconstruction_loss: 1433.5250 - kl_loss: 36.3575
# Epoch 69/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1470.9954 - reconstruction_loss: 1433.8346 - kl_loss: 36.4730
# Epoch 70/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1468.7143 - reconstruction_loss: 1433.9706 - kl_loss: 36.4649
# Epoch 71/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1469.6804 - reconstruction_loss: 1433.7181 - kl_loss: 36.5261
# Epoch 72/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1472.1445 - reconstruction_loss: 1433.2450 - kl_loss: 36.4580
# Epoch 73/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1468.0607 - reconstruction_loss: 1433.2346 - kl_loss: 36.5079
# Epoch 74/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1470.1545 - reconstruction_loss: 1432.7050 - kl_loss: 36.4733
# Epoch 75/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1467.3147 - reconstruction_loss: 1431.7769 - kl_loss: 36.5093
# Epoch 76/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1469.4396 - reconstruction_loss: 1430.6313 - kl_loss: 36.6454
# Epoch 77/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1471.2328 - reconstruction_loss: 1431.9637 - kl_loss: 36.5664
# Epoch 78/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1467.0937 - reconstruction_loss: 1431.6554 - kl_loss: 36.7138
# Epoch 79/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1466.3861 - reconstruction_loss: 1432.0349 - kl_loss: 36.7012
# Epoch 80/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1467.2815 - reconstruction_loss: 1432.2321 - kl_loss: 36.6416
# Epoch 81/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1466.0497 - reconstruction_loss: 1431.4098 - kl_loss: 36.7747
# Epoch 82/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1465.0294 - reconstruction_loss: 1430.7206 - kl_loss: 36.7537
# Epoch 83/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1465.9045 - reconstruction_loss: 1430.2061 - kl_loss: 36.7770
# Epoch 84/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1469.2422 - reconstruction_loss: 1430.5696 - kl_loss: 36.7927
# Epoch 85/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1467.6047 - reconstruction_loss: 1429.9286 - kl_loss: 36.7415
# Epoch 86/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1466.9378 - reconstruction_loss: 1429.7473 - kl_loss: 36.8752
# Epoch 87/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1464.7658 - reconstruction_loss: 1429.8073 - kl_loss: 36.8206
# Epoch 88/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1462.1306 - reconstruction_loss: 1429.5613 - kl_loss: 37.0187
# Epoch 89/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1467.1399 - reconstruction_loss: 1429.1342 - kl_loss: 36.8849
# Epoch 90/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1469.3255 - reconstruction_loss: 1429.8105 - kl_loss: 36.9755
# Epoch 91/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1465.7714 - reconstruction_loss: 1429.0929 - kl_loss: 36.9009
# Epoch 92/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1464.9935 - reconstruction_loss: 1427.8529 - kl_loss: 37.0111
# Epoch 93/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1463.2654 - reconstruction_loss: 1428.3137 - kl_loss: 36.9033
# Epoch 94/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1466.1555 - reconstruction_loss: 1428.9216 - kl_loss: 37.1298
# Epoch 95/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1467.1118 - reconstruction_loss: 1428.3417 - kl_loss: 37.0750
# Epoch 96/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1465.0004 - reconstruction_loss: 1428.3168 - kl_loss: 37.0737
# Epoch 97/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1461.1469 - reconstruction_loss: 1428.2465 - kl_loss: 37.0582
# Epoch 98/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1463.9255 - reconstruction_loss: 1427.2742 - kl_loss: 37.1883
# Epoch 99/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1465.1088 - reconstruction_loss: 1426.6925 - kl_loss: 37.1098
# Epoch 100/100
# 79/79 [==============================] - 11s 140ms/step - loss: 1465.8582 - reconstruction_loss: 1427.5685 - kl_loss: 37.1846

# %%
print("The dimension of the x_test are: ",x_test.shape)
# Out:
# The dimension of the x_test are:  (2500, 50, 50, 1)

# %%
encoded_data = encoder.predict(x_test)
# Out:
# 79/79 [==============================] - 0s 1ms/step

# %%
im1 = decoder.predict(encoded_data[0])
# Out:
# 79/79 [==============================] - 1s 12ms/step

# %%
im1.shape
# Out:
# (2500, 50, 50, 1)

# %%
# Create 5 sample images
num_images = 5
image_shape = (50, 50, 1)

# Create a figure with two grids (top and bottom)
fig, axs = plt.subplots(2, num_images, figsize=(12, 4))

# Titles for the grids
titles = ["Original", "Generated"]

# Generate and display the images in the grids
for i in range(num_images):
    original_image = x_test[i]  # Replace with your actual image data
    generated_image = im1[i]  # Replace with your actual generated image data

    # Display original image in the top grid
    axs[0, i].imshow(original_image, cmap='gray')
    #axs[0, i].set_title(titles[0])
    axs[0, i].axis('off')

    # Display generated image in the bottom grid
    axs[1, i].imshow(generated_image, cmap='gray')
    #axs[1, i].set_title(titles[1])
    axs[1, i].axis('off')

# Add titles to the rows
for i in range(2):
    axs[i, 2].set_title(titles[i], loc='center')

# Adjust spacing between subplots
plt.subplots_adjust(wspace=0.4)

# Show the plot
plt.show()
